# %% [markdown]
# <a href="https://colab.research.google.com/github/dhivyasreedhar/Spoken_Digit_Recognition/blob/main/audioplt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile

# %%
samplerate,data=wavfile.read('/content/drive/MyDrive/recordings/0_george_0.wav')

# %%
samplerate
# Out:
# 8000

# %%
data.shape[0]/8000
# Out:
# 0.298

# %%
plt.plot(data)

# %%
#Plot Using Librosa Module
# !pip install librosa

# %%
import librosa
import librosa.display

# %%
y,sr=librosa.load('/content/drive/MyDrive/recordings/0_george_0.wav',duration=10)
plt.figure()
plt.subplot(2,1,1)
librosa.display.waveplot(y,sr=sr)
plt.title('Monophonic')
# Out:
# Text(0.5, 1.0, 'Monophonic')

# %%
y,sr=librosa.load('/content/drive/MyDrive/recordings/0_george_0.wav',duration=10)
y_harm,y_perc=librosa.effects.hpss(y)
plt.subplot(2,1,2)
librosa.display.waveplot(y_harm,sr=sr,alpha=0.25)
librosa.display.waveplot(y_perc,sr=sr,color='r',alpha=0.5)
plt.title('Harmonic+Percussive')
plt.tight_layout()
plt.savefig('signal.png')

# %%
# !pip install dtw
# Out:
# ...
#   Created wheel for dtw: filename=dtw-1.4.0-cp37-none-any.whl size=5316 sha256=be2956d46da935066adf9699585e72a047c66b92599e7ad192050f57f808813f
#   Stored in directory: /root/.cache/pip/wheels/8c/8b/7a/947d67b53cd54948890a173527b0470ef56998812fc9d0a803
# Successfully built dtw
# ...

# %%
S,phase=librosa.magphase(librosa.stft(y=y))
librosa.display.specshow(librosa.amplitude_to_db(S,ref=np.max),y_axis='log',x_axis='time')
plt.title('log Power Spectogram')
plt.tight_layout()
plt.savefig('spectogram.png')
